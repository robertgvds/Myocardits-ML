# %% [markdown]
# # TREINAMENTO REDE KCL-CNN v4.2KCL.70e.2SL
#
# > Sem uma Conv2D, MaxPooling2D e Dropout
#
# > Adição de camadas de Augmentation COM RANDOM INVERT
#
# > Com separação de indivíduo

# %% [markdown]
# ## Constantes

# %%
# REDE UTILIZADA:
MODEL_TYPE = 'kcl-cnn'

# DATASET UTILIZADO:
DATASET_TYPE = 'selected-localized'
ehCompleto = True

# PARÂMETROS UTILIZADOS:

EPOCHS = 70

BATCH = 32

SIZE = 100

TARGET = (100, 100)

SEED = 10

N_SPLITS = 5

VERSION = 'v4.2KCL.20e.2SL'

# %%
# INDIVÍDUOS EM CADA SPLIT

NORMAL_SPLITS = [[9, 10, 12, 15],
                 [1,8,11],
                 [4,5,14],
                 [2,7,13],
                 [3,6,16]]

if ehCompleto:
    SICK_SPLITS = [[18, 29, 32, 35, 41, 43, 45],
                   [19, 20, 27, 34, 42],
                   [17, 23, 30, 33, 38],
                   [22, 28, 31, 36, 37, 40, 44, 47],
                   [21, 24, 25, 25, 39, 46]]
else:
    SICK_SPLITS = [[24, 33, 35, 41],
                   [25, 32, 36, 42],
                   [26, 31, 37, 43],
                   [27, 30, 39, 45],
                   [28, 29, 38, 44]]

# %% [markdown]
# ## Configurando Ambiente

# %%
# !nvidia-smi
# Out:
# Tue Oct  8 13:06:28 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.90.07              Driver Version: 550.90.07      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   44C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  Tesla T4                       Off |   00000000:00:05.0 Off |                    0 |
# | N/A   40C    P8              9W /   70W |       1MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !pip install efficientnet
# Out:
# Collecting efficientnet
#   Downloading efficientnet-1.1.1-py3-none-any.whl.metadata (6.4 kB)
# Collecting keras-applications<=1.0.8,>=1.0.7 (from efficientnet)
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: scikit-image in /opt/conda/lib/python3.10/site-packages (from efficientnet) (0.22.0)
# Requirement already satisfied: numpy>=1.9.1 in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (1.26.4)
# Requirement already satisfied: h5py in /opt/conda/lib/python3.10/site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet) (3.10.0)
# Requirement already satisfied: scipy>=1.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet) (1.11.4)
# Requirement already satisfied: networkx>=2.8 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet) (3.2.1)
# Requirement already satisfied: pillow>=9.0.1 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet) (9.5.0)
# Requirement already satisfied: imageio>=2.27 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet) (2.33.1)
# Requirement already satisfied: tifffile>=2022.8.12 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet) (2023.12.9)
# Requirement already satisfied: packaging>=21 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet) (21.3)
# Requirement already satisfied: lazy_loader>=0.3 in /opt/conda/lib/python3.10/site-packages (from scikit-image->efficientnet) (0.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=21->scikit-image->efficientnet) (3.1.1)
# Downloading efficientnet-1.1.1-py3-none-any.whl (18 kB)
# Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.7/50.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: keras-applications, efficientnet
# Successfully installed efficientnet-1.1.1 keras-applications-1.0.8

# %% [markdown]
# ## Bibliotecas e Diretórios

# %%
# BIBLIOTECAS GERAIS

import os
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import sys
import random

# BIBLIOTECAS DEEP LEARNING

import datetime
import tensorflow as tf
from tensorflow.keras import layers

from sklearn.metrics import auc, classification_report, confusion_matrix, roc_curve
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.callbacks import CSVLogger
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.preprocessing import image

from efficientnet.tfkeras import EfficientNetB7
# Out:
# 2024-10-08 13:06:44.276319: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-10-08 13:06:44.276434: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-10-08 13:06:44.416149: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
# DIRETÓRIOS

DATASET_PATH = f'/kaggle/input/myocardits-dataset-{DATASET_TYPE}/'
RESULTS_PATH = f'/kaggle/working/{DATASET_TYPE}'

NORMAL_INDIVIDUOS = [f'Individuo_{i:02}' for i in range(1, 17)]
SICK_INDIVIDUOS = [f'Individuo_{i:02}' for i in range(17, 48)]

# Pasta com resultados
if not os.path.exists(f'{DATASET_TYPE}'):
    os.mkdir(f'{DATASET_TYPE}')
    
# Configurando seeds
np.random.seed(SEED)
random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Carregamento e Processamento de Imagens

# %%
# PROCESSAMENTO DE IMAGENS

num_imagens = 0

def processamento_imagens(caminho):
    global num_imagens
    
    img = Image.open(caminho)    
    img = np.array(img)
    
    resize_and_rescale = tf.keras.Sequential([
      layers.Resizing(100,100),
      layers.Rescaling(1./255)
    ])
    
    img = resize_and_rescale(img)
    img = tf.cast(img, tf.float32)  
    img = np.array(img)
    
    num_imagens += 1
    sys.stdout.write("\rNumero de imagens carregados: %i" % num_imagens)
    sys.stdout.flush()
    
    return img

# CARREGAMENTO DE IMAGENS

def carregar_imagens(diretorio):
    imagens = []
    
    for pasta_atual, subpastas, arquivos in os.walk(diretorio):
        for arquivo in arquivos:
            if arquivo.endswith(".jpg") or arquivo.endswith(".png"):
                caminho = os.path.join(pasta_atual, arquivo)
            
                #print(f"Processando imagem: {caminho}")
            
                imagem = processamento_imagens(caminho)
                imagens.append(imagem)
    
    return imagens

# %%
# PERCORRENDO O DIRETÓRIO

normal_paths = []
for individuo in NORMAL_INDIVIDUOS:
    directory = f'{DATASET_PATH}/Normal/{individuo}/'
    normal_paths.append(directory)

sick_paths = []
for individuo in SICK_INDIVIDUOS:
    directory = f'{DATASET_PATH}/Sick/{individuo}/'
    sick_paths.append(directory)

# SEPARAÇÃO DOS DATASETS ENTRE OS SPLITS

normal_splits = [[],[],[],[],[]]
sick_splits = [[],[],[],[],[]]

for split in range(N_SPLITS):
    normal_splits[split].extend(normal_paths[i-1] for i in NORMAL_SPLITS[split])
    sick_splits[split].extend(sick_paths[i-17] for i in SICK_SPLITS[split])

# CARREGANDO E PROCESSANDO AS IMAGENS

print('\nIniciando carregamento e processamento das imagens..............!')

print('\nPacientes normais:')
normal_datasets = []
for split in normal_splits:
    imagens = []
    for individuo in split:
        imagens.extend(carregar_imagens(individuo))
    normal_datasets.append(imagens)

num_imagens = 0

print('\nPacientes doentes:')
sick_datasets = []
for split in sick_splits:
    imagens = []
    for individuo in split:
        imagens.extend(carregar_imagens(individuo))
    sick_datasets.append(imagens)

num_imagens = 0

# DATASETS SEPRADAOS EM 5 SPLITS

x_data = [[],[],[],[],[]]
y_data = [[],[],[],[],[]]

print('\n\nNumero de imagens por split:')
for i in range(N_SPLITS):
    x_data[i].extend(path for path in normal_datasets[i])
    y_data[i].extend([1, 0] for path in normal_datasets[i])
    x_data[i].extend(path for path in sick_datasets[i])
    y_data[i].extend([0, 1] for path in sick_datasets[i])
    print(f'Split {i+1}: {len(x_data[i])} imagens ({len(normal_datasets[i])} saudáveis e {len(sick_datasets[i])} doentes).')
# Out:
# Iniciando carregamento e processamento das imagens..............!
#
# Pacientes normais:
# Numero de imagens carregados: 137
# Pacientes doentes:
# Numero de imagens carregados: 257
#
# Numero de imagens por split:
# Split 1: 89 imagens (32 saudáveis e 57 doentes).
# Split 2: 72 imagens (27 saudáveis e 45 doentes).
# Split 3: 69 imagens (26 saudáveis e 43 doentes).
# Split 4: 90 imagens (26 saudáveis e 64 doentes).
# Split 5: 74 imagens (26 saudáveis e 48 doentes).

# %% [markdown]
# # Treinamento

# %% [markdown]
# ## Configurando a Rede

# %%
# Arquitetura CNN
def random_invert_img(x, factor):
    # Função para aplicar inversão e contraste de forma condicional.
    return tf.cond(
        tf.less(tf.random.uniform([]), factor),  # Se tf.random.uniform for menor que o fator
        lambda: tf.image.adjust_contrast((1 - x) - 0.6, 1.0),  # Aplica a inversão e ajusta o contraste
        lambda: x  # Caso contrário, retorna a imagem original
    )

def random_invert_layer(factor):
    # Camada personalizada para inversão de imagem com especificação de output_shape.
    return layers.Lambda(lambda x: random_invert_img(x, factor), output_shape=lambda s: s)

def cnn_model(input_shape, num_classes):
    inputs = layers.Input(shape=input_shape)
    
    # Aumentação de dados
    x = layers.RandomFlip("horizontal_and_vertical")(inputs)
    x = layers.RandomRotation(0.2)(x)
    x = layers.RandomContrast(0.5)(x)
    x = layers.RandomZoom(0.2)(x)
    
    # Aplicação de inversão personalizada
    x = random_invert_layer(0.5)(x)
    
    # Camadas convolucionais
    x = layers.Conv2D(32, 3, activation='relu')(inputs)
    x = layers.MaxPooling2D()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Conv2D(64, 3, activation='relu')(x)
    x = layers.MaxPooling2D()(x)
    x = layers.Dropout(0.2)(x)
    x = layers.Flatten()(x)
    
    # Camadas densas
    x = layers.Dense(100, activation='relu')(x)
    x = layers.Dropout(0.2)(x)
    outputs = layers.Dense(num_classes, activation='softmax')(x)
    
    # Criação do modelo
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.summary()
    return model

# %% [markdown]
# ## Separação de Dados e Treinamento

# %%
# SEPARAÇÃO DE DADOS E TREINAMENTO

results = {
    "train_accuracies": [],
    "valid_accuracies": [],
    "test_accuracies": [],

    "train_matrixs": [],
    "valid_matrixs": [],
    "test_matrixs": [],
    
    "test_loss": [],
    "test_accuracy": [],
    
    "reports": [],
    "AUC": [],
    "times": [], 
    "historys": []
}

# TREINAMENTO POR FOLDS

for fold in range(N_SPLITS):

    print(f'\n\nFOLD {fold+1}:')

    # SEPARAÇÃO DO TREINO, TESTE E VALIDAÇÃO
    
    x_test = np.array(x_data[fold])
    y_test = np.array(y_data[fold])
    
    folds = [0, 1, 2, 3, 4]
    folds.remove(fold)

    x_valid = np.array(x_data[folds[0]])
    y_valid = np.array(y_data[folds[0]])
    folds.remove(folds[0])

    x_train, y_train = [], []
    for i in folds:
        x_train.extend(x_data[i])
        y_train.extend(y_data[i])
    x_train = np.array(x_train)
    y_train = np.array(y_train)

    print(f'Numero de imagens no treinamento: {len(x_train)} imagens.')
    print(f'Numero de imagens na validação: {len(x_valid)} imagens.')
    print(f'Numero de imagens no teste: {len(x_test)} imagens.')
    

    # ARQUITETURA E COMPILAÇÃO
    model = cnn_model((SIZE, SIZE, 3), 2)
    OPTIMIZER = AdamW(weight_decay=0.004)
    
    # Compilação do modelo
    model.compile(loss='categorical_crossentropy',
                  optimizer=OPTIMIZER,
                  metrics=['categorical_accuracy'])

    
    # TREINAMENTO
    print('\nIniciando o treinamento.........................................!\n')

    calback = CSVLogger(RESULTS_PATH + f'/logger_fold{fold+1}.log')

    start = datetime.datetime.now()
    
    history = model.fit(x_train, y_train,
                        epochs=EPOCHS,
                        validation_data=(x_valid, y_valid),
                        callbacks=[calback])
    
    results["historys"].append(history)

    end = datetime.datetime.now()
    results["times"].append(end - start)

    # Salvando o modelo
    model.save(RESULTS_PATH + f'/{DATASET_TYPE}-CNN-{fold+1}.keras')

    # TESTE
    print("\nTestando imagens................................................!\n")
    
    test_loss, test_accuracy = model.evaluate(x_test, y_test)
    results["test_loss"].append(test_loss)
    results["test_accuracy"].append(test_accuracy)
    
    print(f"loss: {test_loss}")
    print(f"accuracy: {test_accuracy}")

    # ARMAZENAMENTO DOS INFORMACOES
    print("\nCalculando métricas.............................................!\n")

    # METRICAS DO TREINO
    train_predicts = model.predict(x_train).argmax(axis=1)
    train_actuals = y_train.argmax(axis=1)
    
    # Matriz de confusão
    train_matrix = confusion_matrix(train_actuals, train_predicts)
    train_accuracy = np.trace(train_matrix)/np.sum(train_matrix)
    
    results["train_accuracies"].append(train_accuracy)
    results["train_matrixs"].append(train_matrix)

    # METRICAS DO VALIDAÇÃO
    valid_predicts = model.predict(x_valid).argmax(axis=1)
    valid_actuals = y_valid.argmax(axis=1)
    
    # Matriz de confusão
    valid_matrix = confusion_matrix(valid_actuals, valid_predicts)
    valid_accuracy = np.trace(valid_matrix)/np.sum(valid_matrix)
    
    results["valid_accuracies"].append(valid_accuracy)
    results["valid_matrixs"].append(valid_matrix)

    # METRICAS DO TESTE
    test_predicts = model.predict(x_test).argmax(axis=1)
    test_actuals = y_test.argmax(axis=1)
    
    # Matriz de confusão
    test_matrix = confusion_matrix(test_actuals, test_predicts)
    test_accuracy = np.trace(test_matrix)/np.sum(test_matrix)
    
    results["test_accuracies"].append(test_accuracy)
    results["test_matrixs"].append(test_matrix)

    # Calculando ROC e RELATORIO DE CLASSIFICAÇÃO
    fpr, tpr, _ = roc_curve(test_actuals, test_predicts, pos_label=1)
    results["AUC"].append(auc(fpr, tpr))
    
    results["reports"].append(classification_report(test_actuals, test_predicts, zero_division=1))
# Out:
# FOLD 1:
# Numero de imagens no treinamento: 233 imagens.
# Numero de imagens na validação: 72 imagens.
# Numero de imagens no teste: 89 imagens.
# Model: "functional_395"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_394 (InputLayer)    │ (None, 100, 100, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 33856)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 100)            │     3,385,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 2)              │           202 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,405,294 (12.99 MB)
#  Trainable params: 3,405,294 (12.99 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento.........................................!
#
# Epoch 1/70
# 5/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.6686 - loss: 1.2531
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1728392833.816788      78 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# W0000 00:00:1728392833.833597      78 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 697ms/step - categorical_accuracy: 0.6047 - loss: 1.2159
# W0000 00:00:1728392839.256146      78 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 15s 881ms/step - categorical_accuracy: 0.5904 - loss: 1.2066 - val_categorical_accuracy: 0.3750 - val_loss: 0.7092
# Epoch 2/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.3932 - loss: 0.7230 - val_categorical_accuracy: 0.6250 - val_loss: 0.6663
# Epoch 3/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.6840 - loss: 0.6694 - val_categorical_accuracy: 0.6250 - val_loss: 0.6600
# Epoch 4/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.6755 - loss: 0.6433 - val_categorical_accuracy: 0.6250 - val_loss: 0.6542
# Epoch 5/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.6855 - loss: 0.6377 - val_categorical_accuracy: 0.6250 - val_loss: 0.6523
# Epoch 6/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.6855 - loss: 0.6211 - val_categorical_accuracy: 0.6250 - val_loss: 0.6518
# Epoch 7/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.6855 - loss: 0.6271 - val_categorical_accuracy: 0.6250 - val_loss: 0.6529
# Epoch 8/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.6855 - loss: 0.5952 - val_categorical_accuracy: 0.6250 - val_loss: 0.6475
# Epoch 9/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.7032 - loss: 0.5693 - val_categorical_accuracy: 0.6250 - val_loss: 0.6488
# Epoch 10/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.7155 - loss: 0.5642 - val_categorical_accuracy: 0.5833 - val_loss: 0.6570
# Epoch 11/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.7750 - loss: 0.5189 - val_categorical_accuracy: 0.6389 - val_loss: 0.6542
# Epoch 12/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.7684 - loss: 0.4799 - val_categorical_accuracy: 0.6250 - val_loss: 0.6791
# Epoch 13/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.7476 - loss: 0.4830 - val_categorical_accuracy: 0.5556 - val_loss: 0.6856
# Epoch 14/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.8109 - loss: 0.4330 - val_categorical_accuracy: 0.5972 - val_loss: 0.6769
# Epoch 15/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.8593 - loss: 0.3500 - val_categorical_accuracy: 0.6111 - val_loss: 0.6962
# Epoch 16/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.8786 - loss: 0.3333 - val_categorical_accuracy: 0.6111 - val_loss: 0.6996
# Epoch 17/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.8886 - loss: 0.2834 - val_categorical_accuracy: 0.6250 - val_loss: 0.7209
# Epoch 18/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.8953 - loss: 0.2768 - val_categorical_accuracy: 0.6389 - val_loss: 0.7662
# Epoch 19/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.
70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0023 - val_categorical_accuracy: 0.5694 - val_loss: 2.2423
# Epoch 54/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 8.2966e-04 - val_categorical_accuracy: 0.5833 - val_loss: 2.3379
# Epoch 55/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0012 - val_categorical_accuracy: 0.5694 - val_loss: 2.3106
# Epoch 56/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 8.6153e-04 - val_categorical_accuracy: 0.5833 - val_loss: 2.3018
# Epoch 57/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0017 - val_categorical_accuracy: 0.5833 - val_loss: 2.3104
# Epoch 58/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0013 - val_categorical_accuracy: 0.5694 - val_loss: 2.3387
# Epoch 59/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 8.9839e-04 - val_categorical_accuracy: 0.5556 - val_loss: 2.4807
# Epoch 60/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0023 - val_categorical_accuracy: 0.5833 - val_loss: 2.1915
# Epoch 61/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0015 - val_categorical_accuracy: 0.5694 - val_loss: 2.1767
# Epoch 62/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0015 - val_categorical_accuracy: 0.5694 - val_loss: 2.3350
# Epoch 63/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0080 - val_categorical_accuracy: 0.5833 - val_loss: 1.9108
# Epoch 64/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0066 - val_categorical_accuracy: 0.5694 - val_loss: 2.3648
# Epoch 65/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0034 - val_categorical_accuracy: 0.5694 - val_loss: 2.2716
# Epoch 66/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0030 - val_categorical_accuracy: 0.5833 - val_loss: 2.2180
# Epoch 67/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0027 - val_categorical_accuracy: 0.5556 - val_loss: 2.6787
# Epoch 68/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0027 - val_categorical_accuracy: 0.5556 - val_loss: 2.5116
# Epoch 69/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0026 - val_categorical_accuracy: 0.5694 - val_loss: 2.2732
# Epoch 70/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0012 - val_categorical_accuracy: 0.5556 - val_loss: 2.4090
#
# Testando imagens................................................!
#
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 395ms/step - categorical_accuracy: 0.4835 - loss: 4.2726
# loss: 3.4337384700775146
# accuracy: 0.584269642829895
#
# Calculando métricas.............................................!
#
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 2s 287ms/step
# W0000 00:00:1728392849.798706      77 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
#
#
# FOLD 2:
# Numero de imagens no treinamento: 233 imagens.
# Numero de imagens na validação: 89 imagens.
# Numero de imagens no teste: 72 imagens.
# Model: "functional_397"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_395 (InputLayer)    │ (None, 100, 100, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 33856)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 100)            │     3,385,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 2)              │           202 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,405,294 (12.99 MB)
#  Trainable params: 3,405,294 (12.99 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento.........................................!
#
# Epoch 1/70
# 5/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.4196 - loss: 1.2150
# W0000 00:00:1728392856.209251      78 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 559ms/step - categorical_accuracy: 0.4251 - loss: 1.1608
# W0000 00:00:1728392860.661464      78 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 10s 681ms/step - categorical_accuracy: 0.4246 - loss: 1.1478 - val_categorical_accuracy: 0.3708 - val_loss: 0.6963
# Epoch 2/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.4491 - loss: 0.6970 - val_categorical_accuracy: 0.6404 - val_loss: 0.6891
# Epoch 3/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - categorical_accuracy: 0.6795 - loss: 0.6798 - val_categorical_accuracy: 0.6404 - val_loss: 0.6681
# Epoch 4/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.6855 - loss: 0.6482 - val_categorical_accuracy: 0.6404 - val_loss: 0.6467
# Epoch 5/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.6855 - loss: 0.6524 - val_categorical_accuracy: 0.6404 - val_loss: 0.6580
# Epoch 6/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.6855 - loss: 0.6299 - val_categorical_accuracy: 0.6404 - val_loss: 0.6501
# Epoch 7/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.6855 - loss: 0.6333 - val_categorical_accuracy: 0.6404 - val_loss: 0.6504
# Epoch 8/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.6855 - loss: 0.6319 - val_categorical_accuracy: 0.6404 - val_loss: 0.6535
# Epoch 9/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.6855 - loss: 0.6054 - val_categorical_accuracy: 0.6404 - val_loss: 0.6552
# Epoch 10/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.
70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9873 - loss: 0.0519 - val_categorical_accuracy: 0.5730 - val_loss: 2.1724
# Epoch 55/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9944 - loss: 0.0396 - val_categorical_accuracy: 0.6180 - val_loss: 2.1412
# Epoch 56/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9976 - loss: 0.0294 - val_categorical_accuracy: 0.5955 - val_loss: 1.9269
# Epoch 57/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0492 - val_categorical_accuracy: 0.5955 - val_loss: 1.6673
# Epoch 58/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0407 - val_categorical_accuracy: 0.5618 - val_loss: 1.8750
# Epoch 59/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9841 - loss: 0.0478 - val_categorical_accuracy: 0.5955 - val_loss: 2.4185
# Epoch 60/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9885 - loss: 0.0462 - val_categorical_accuracy: 0.5393 - val_loss: 1.8597
# Epoch 61/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0439 - val_categorical_accuracy: 0.5618 - val_loss: 1.9053
# Epoch 62/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0263 - val_categorical_accuracy: 0.5618 - val_loss: 2.1790
# Epoch 63/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9871 - loss: 0.0524 - val_categorical_accuracy: 0.4831 - val_loss: 1.9632
# Epoch 64/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9901 - loss: 0.0593 - val_categorical_accuracy: 0.5955 - val_loss: 2.4926
# Epoch 65/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9881 - loss: 0.0354 - val_categorical_accuracy: 0.5506 - val_loss: 1.8411
# Epoch 66/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9953 - loss: 0.0521 - val_categorical_accuracy: 0.5506 - val_loss: 1.8881
# Epoch 67/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9935 - loss: 0.0382 - val_categorical_accuracy: 0.5618 - val_loss: 2.3789
# Epoch 68/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9905 - loss: 0.0348 - val_categorical_accuracy: 0.5281 - val_loss: 1.8406
# Epoch 69/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9915 - loss: 0.0397 - val_categorical_accuracy: 0.5730 - val_loss: 1.7117
# Epoch 70/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0408 - val_categorical_accuracy: 0.6067 - val_loss: 2.0842
#
# Testando imagens................................................!
#
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 301ms/step - categorical_accuracy: 0.4032 - loss: 3.1223
# loss: 2.546980381011963
# accuracy: 0.47826087474823
#
# Calculando métricas.............................................!
#
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 218ms/step
# W0000 00:00:1728392892.311074      77 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 78ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
#
#
# FOLD 4:
# Numero de imagens no treinamento: 215 imagens.
# Numero de imagens na validação: 89 imagens.
# Numero de imagens no teste: 90 imagens.
# Model: "functional_401"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_397 (InputLayer)    │ (None, 100, 100, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_6 (Conv2D)               │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_6 (MaxPooling2D)  │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_7 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_7 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 33856)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 100)            │     3,385,700 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 100)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 2)              │           202 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,405,294 (12.99 MB)
#  Trainable params: 3,405,294 (12.99 MB)
#  Non-trainable params: 0 (0.00 B)
# Iniciando o treinamento.........................................!
#
# Epoch 1/70
# 5/7 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.5968 - loss: 0.7617
# W0000 00:00:1728392898.768461      79 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 891ms/step - categorical_accuracy: 0.5898 - loss: 0.7586
# W0000 00:00:1728392904.561985      79 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 11s 1s/step - categorical_accuracy: 0.5881 - loss: 0.7573 - val_categorical_accuracy: 0.6404 - val_loss: 0.6462
# Epoch 2/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - categorical_accuracy: 0.6316 - loss: 0.6437 - val_categorical_accuracy: 0.6404 - val_loss: 0.6620
# Epoch 3/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 0.6316 - loss: 0.6406 - val_categorical_accuracy: 0.6404 - val_loss: 0.6507
# Epoch 4/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.6295 - loss: 0.6099 - val_categorical_accuracy: 0.6404 - val_loss: 0.6492
# Epoch 5/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.6963 - loss: 0.5712 - val_categorical_accuracy: 0.5955 - val_loss: 0.6621
# Epoch 6/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.7519 - loss: 0.5288 - val_categorical_accuracy: 0.6067 - val_loss: 0.6551
# Epoch 7/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.8006 - loss: 0.4717 - val_categorical_accuracy: 0.6067 - val_loss: 0.6675
# Epoch 8/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 0.8058 - loss: 0.4017 - val_categorical_accuracy: 0.5618 - val_loss: 0.7059
# Epoch 9/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.8359 - loss: 0.3583 - val_categorical_accuracy: 0.4944 - val_loss: 0.8197
# Epoch 10/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.7988 - loss: 0.4094 - val_categorical_accuracy: 0.5281 - val_loss: 0.7492
# Epoch 11/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9238 - loss: 0.2742 - val_categorical_accuracy: 0.5955 - val_loss: 0.7757
# Epoch 12/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9418 - loss: 0.1902 - val_categorical_accuracy: 0.5955 - val_loss: 0.8888
# Epoch 13/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9258 - loss: 0.1686 - val_categorical_accuracy: 0.5843 - val_loss: 0.9815
# Epoch 14/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9284 - loss: 0.1451 - val_categorical_accuracy: 0.4831 - val_loss: 1.0459
# Epoch 15/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9657 - loss: 0.1219 - val_categorical_accuracy: 0.4944 - val_loss: 1.1011
# Epoch 16/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9668 - loss: 0.1009 - val_categorical_accuracy: 0.5506 - val_loss: 1.1377
# Epoch 17/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9824 - loss: 0.0574 - val_categorical_accuracy: 0.5955 - val_loss: 1.2970
# Epoch 18/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9893 - loss: 0.0591 - val_categorical_accuracy: 0.5169 - val_loss: 1.3296
# Epoch 19/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9779 - loss: 0.0503 - val_categorical_accuracy: 0.5169 - val_loss: 1.4127
# Epoch 20/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9856 - loss: 0.0581 - val_categorical_accuracy: 0.5506 - val_loss: 1.3417
# Epoch 21/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 0.0269 - val_categorical_accuracy: 0.5169 - val_loss: 1.4166
# Epoch 22/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 0.9932 - loss: 0.0260 - val_categorical_accuracy: 0.5393 - val_loss: 1.5220
# Epoch 23/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 0.0222 - val_categorical_accuracy: 0.5056 - val_loss: 1.7070
# Epoch 24/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 0.0164 - val_categorical_accuracy: 0.5506 - val_loss: 1.7043
# Epoch 25/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 0.0087 - val_categorical_accuracy: 0.5281 - val_loss: 1.7513
# Epoch 26/70
# ...
# Epoch 60/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 0.0014 - val_categorical_accuracy: 0.5506 - val_loss: 2.3491
# Epoch 61/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 9.7872e-04 - val_categorical_accuracy: 0.5169 - val_loss: 2.3928
# Epoch 62/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 5.9160e-04 - val_categorical_accuracy: 0.5393 - val_loss: 2.4145
# Epoch 63/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 5.0595e-04 - val_categorical_accuracy: 0.5281 - val_loss: 2.4402
# Epoch 64/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - categorical_accuracy: 1.0000 - loss: 5.4494e-04 - val_categorical_accuracy: 0.5393 - val_loss: 2.4725
# Epoch 65/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - categorical_accuracy: 1.0000 - loss: 5.6735e-04 - val_categorical_accuracy: 0.5281 - val_loss: 2.5180
# Epoch 66/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 3.0709e-04 - val_categorical_accuracy: 0.5281 - val_loss: 2.5505
# Epoch 67/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 3.9699e-04 - val_categorical_accuracy: 0.5281 - val_loss: 2.5661
# Epoch 68/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 2.1218e-04 - val_categorical_accuracy: 0.5393 - val_loss: 2.5793
# Epoch 69/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 0.0015 - val_categorical_accuracy: 0.5281 - val_loss: 2.5762
# Epoch 70/70
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - categorical_accuracy: 1.0000 - loss: 8.7449e-04 - val_categorical_accuracy: 0.5393 - val_loss: 2.5542
#
# Testando imagens................................................!
#
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 415ms/step - categorical_accuracy: 0.5311 - loss: 2.2981
# loss: 2.322179079055786
# accuracy: 0.5777778029441833
#
# Calculando métricas.............................................!
#
# 1/7 ━━━━━━━━━━━━━━━━━━━━ 1s 217ms/step
# W0000 00:00:1728392914.328649      77 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 77ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step
70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0119 - val_categorical_accuracy: 0.5955 - val_loss: 2.5811
# Epoch 56/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 1.0000 - loss: 0.0184 - val_categorical_accuracy: 0.5843 - val_loss: 2.8552
# Epoch 57/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9980 - loss: 0.0110 - val_categorical_accuracy: 0.5730 - val_loss: 2.6836
# Epoch 58/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.9973 - loss: 0.0114 - val_categorical_accuracy: 0.5843 - val_loss: 2.5813
# Epoch 59/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9985 - loss: 0.0148 - val_categorical_accuracy: 0.5843 - val_loss: 2.6407
# Epoch 60/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9985 - loss: 0.0043 - val_categorical_accuracy: 0.5506 - val_loss: 2.8373
# Epoch 61/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9864 - loss: 0.0199 - val_categorical_accuracy: 0.5843 - val_loss: 2.8228
# Epoch 62/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9964 - loss: 0.0061 - val_categorical_accuracy: 0.5506 - val_loss: 2.6489
# Epoch 63/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0122 - val_categorical_accuracy: 0.5506 - val_loss: 2.6629
# Epoch 64/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0187 - val_categorical_accuracy: 0.5506 - val_loss: 2.7130
# Epoch 65/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9985 - loss: 0.0203 - val_categorical_accuracy: 0.5618 - val_loss: 2.7555
# Epoch 66/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - categorical_accuracy: 0.9880 - loss: 0.0194 - val_categorical_accuracy: 0.5618 - val_loss: 2.7378
# Epoch 67/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9900 - loss: 0.0196 - val_categorical_accuracy: 0.5618 - val_loss: 2.7542
# Epoch 68/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 1.0000 - loss: 0.0117 - val_categorical_accuracy: 0.5506 - val_loss: 2.7579
# Epoch 69/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9973 - loss: 0.0124 - val_categorical_accuracy: 0.5730 - val_loss: 2.7438
# Epoch 70/70
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - categorical_accuracy: 0.9964 - loss: 0.0087 - val_categorical_accuracy: 0.5843 - val_loss: 3.4316
#
# Testando imagens................................................!
#
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 335ms/step - categorical_accuracy: 0.5317 - loss: 3.9771
# loss: 3.1671946048736572
# accuracy: 0.5945945978164673
#
# Calculando métricas.............................................!
#
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 1s 225ms/step
# W0000 00:00:1728392936.389886      78 graph_launch.cc:671] Fallback to op-by-op mode because memset node breaks graph update
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step

# %% [markdown]
# # Análise de Dados

# %%
# CÁLCULOS DAS MÉTRICAS

# TREINO
total_train_matrix = np.mean(results["train_matrixs"], axis=0)
total_train_accuracy = np.mean(results["train_accuracies"])

# VALIDAÇÃO
total_valid_matrix = np.mean(results["valid_matrixs"], axis=0)
total_valid_accuracy = np.mean(results["valid_accuracies"])

# TESTE
total_test_matrix = np.mean(results["test_matrixs"], axis=0)
total_test_accuracy = np.mean(results["test_accuracies"])

train_metrics = {
    "accuracy": [],
    "loss": [],
    "val_accuracy": [],
    "val_loss": []
}

for item in results["historys"]:   
    history = item.history
    
    accuracy = history['categorical_accuracy']
    loss = history['loss']
    
    val_accuracy = history['val_categorical_accuracy']
    val_loss = history['val_loss']
    
    train_metrics["accuracy"].append(np.mean(accuracy))
    train_metrics["loss"].append(np.mean(loss))
    
    train_metrics["val_accuracy"].append(np.mean(val_accuracy))
    train_metrics["val_loss"].append(np.mean(val_loss))

# %% [markdown]
# ## Plotagem dos Gráficos

# %%
# PLOTAGEM DOS GRÁFICOS DE ACURÁCIA E TREINO POR ÉPOCA

def NetPlot():

    losses=[]
    val_losses=[]
    accuracies=[]
    val_accuracies=[]

    for item in results["historys"]:

        history=item.history
        loss=history['loss']
        val_loss=history['val_loss']
        accuracy=history['categorical_accuracy']
        val_accuracy=history['val_categorical_accuracy']

        losses.append(loss)
        val_losses.append(val_loss)
        accuracies.append(accuracy)
        val_accuracies.append(val_accuracy)

    losses2=np.zeros((1, EPOCHS))
    val_losses2=np.zeros((1, EPOCHS))
    accuracies2=np.zeros((1, EPOCHS))
    val_accuracies2=np.zeros((1, EPOCHS))

    for i in accuracies: accuracies2+=i
    for i in losses: losses2+=i

    for i in val_accuracies: val_accuracies2+=i    
    for i in val_losses: val_losses2+=i

    losses2=(losses2/N_SPLITS).flatten()
    accuracies2=(accuracies2/N_SPLITS).flatten()
    val_losses2=(val_losses2/N_SPLITS).flatten()
    val_accuracies2=(val_accuracies2/N_SPLITS).flatten()

    # print('\nAccuracies: '+ str(accuracies2) +'\nLosses: '+ str(losses2))

    plt.figure('Accuracy Diagram',dpi=600)
    plt.title(f'Accyracy Diagram - {MODEL_TYPE} - {DATASET_TYPE} v{VERSION}')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.plot(accuracies2,color='black')
    plt.plot(val_accuracies2,color='green')
    plt.legend(['Train Data','Validation Data'])

    plt.savefig(f'{RESULTS_PATH}/Accuracy-Diagram-{MODEL_TYPE}-v{VERSION}.jpg')

    plt.figure('Loss Diagram',dpi=600)
    plt.title(f'Loss Diagram - {MODEL_TYPE} - {DATASET_TYPE} v{VERSION}')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.plot(losses2,color='black')
    plt.plot(val_losses2,color='green')
    plt.legend(['Train Data','Validation Data'])

    plt.savefig(f'{RESULTS_PATH}/Loss-Diagram-{MODEL_TYPE}-v{VERSION}.jpg')
    
NetPlot()

# %% [markdown]
# ## Imprimindo Informações

# %%
# IMPRIMINDO DAS INFORMAÇÕES

print(f"TREINAMENTO v{VERSION}\n")

print(f"Modelo: {MODEL_TYPE}\t  Dataset: {DATASET_TYPE}\t ehCompleto? {ehCompleto}")

print("\nParâmetros: ")
print(f"Épocas: {EPOCHS}\t Batch: {BATCH}\t Target Size: {TARGET}")

print("\n__________________________________________________________")
print("\nMÉTRICAS DO TREINO:")
print(f"\nAcurácias do Treino (accuracy): {train_metrics['accuracy']}")
print(f"Perdas do Treino (loss): {train_metrics['loss']}")
print(f"\nMatriz total do Treino:\n{total_train_matrix}")
#print(f"\nMédia das acurácias do Treino: {np.mean(train_metrics['accuracy'])}")
print(f"Acurácia total do Treino: {total_train_accuracy}")

print("\n__________________________________________________________")
print("\nMÉTRICAS DA VALIDAÇÃO:")
print(f"\nAcurácias do Validação (accuracy): {train_metrics['val_accuracy']}")
print(f"Perdas do Validação (loss): {train_metrics['val_loss']}")
print(f"\nMatriz total do Validação:\n{total_valid_matrix}")
#print(f"\nMédia das acurácias da Validação: {np.mean(train_metrics['val_accuracy'])}")
print(f"Acurácia total da Validação: {total_valid_accuracy}")

print("\n__________________________________________________________")
print("\nMÉTRICAS DO TESTE:")
print(f"\nAcurácias do Teste (accuracy): {results['test_accuracy']}")
print(f"Perdas do Teste (loss): {results['test_loss']}")
print(f"\nMatriz total do Teste:\n{total_test_matrix}")
#print(f"\nMédia das acurácias do Teste: {np.mean(history['test_accuracies'])}")
print(f"Acurácia total do Teste: {total_test_accuracy}")

print("\n__________________________________________________________")
print("MÉTRICAS PARA CADA FOLD:\n")
for i in range(len(results["reports"])):
    print(str(results["reports"][i]))
    print(f"\nTempo do Treinamento: {results['times'][i]}\t AUC: {results['AUC'][i]}")
    print(f"Acurácia: {results['test_accuracies'][i]}")
    print(f"Matriz de Confusao:\n{results['test_matrixs'][i]}")
    print("\n__________________________________________________________\n")
# Out:
# TREINAMENTO vv4.2KCL.20e.2SL
#
# Modelo: kcl-cnn	  Dataset: selected-localized	 ehCompleto? True
#
# Parâmetros:
# Épocas: 70	 Batch: 32	 Target Size: (100, 100)
#
# __________________________________________________________
#
# MÉTRICAS DO TREINO:
#
# Acurácias do Treino (accuracy): [0.9229307230029787, 0.884855917096138, 0.9129539889948709, 0.9556810625961849, 0.9139146494013922]
# Perdas do Treino (loss): [0.16263860592901308, 0.23196809008451444, 0.19960232273276363, 0.0939265006596023, 0.18242994545559799]
#
# Matriz total do Treino:
# [[ 78.6   0. ]
#  [  0.  151. ]]
# Acurácia total do Treino: 1.0
#
# __________________________________________________________
#
# MÉTRICAS DA VALIDAÇÃO:
#
# Acurácias do Validação (accuracy): [0.5785714251654489, 0.5534510395356587, 0.5847511947154999, 0.5391653231212071, 0.5935794459921974]
# Perdas do Validação (loss): [1.56995244877679, 1.9420318748269763, 1.4304223673684255, 1.8373008378914424, 1.6957257977553777]
#
# Matriz total do Validação:
# [[ 6.6 24.4]
#  [12.4 42.2]]
# Acurácia total da Validação: 0.5695380774032459
#
# __________________________________________________________
#
# MÉTRICAS DO TESTE:
#
# Acurácias do Teste (accuracy): [0.584269642829895, 0.5555555820465088, 0.47826087474823, 0.5777778029441833, 0.5945945978164673]
# Perdas do Teste (loss): [3.4337384700775146, 2.131371021270752, 2.546980381011963, 2.322179079055786, 3.1671946048736572]
#
# Matriz total do Teste:
# [[ 7.6 19.8]
#  [14.8 36.6]]
# Acurácia total do Teste: 0.5580916920828987
#
# __________________________________________________________
# MÉTRICAS PARA CADA FOLD:
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.25      0.30        32
#            1       0.65      0.77      0.70        57
#
#     accuracy                           0.58        89
#    macro avg       0.51      0.51      0.50        89
# weighted avg       0.55      0.58      0.56        89
#
#
# Tempo do Treinamento: 0:00:23.076228	 AUC: 0.5109649122807017
# Acurácia: 0.5842696629213483
# Matriz de Confusao:
# [[ 8 24]
#  [13 44]]
#
# __________________________________________________________
#
#               precision    recall  f1-score   support
#
#            0       0.38      0.30      0.33        27
#            1       0.63      0.71      0.67        45
#
#     accuracy                           0.56        72
#    macro avg       0.50      0.50      0.50        72
# weighted avg       0.54      0.56      0.54        72
#
#
# Tempo do Treinamento: 0:00:18.916605	 AUC: 0.5037037037037038
# Acurácia: 0.5555555555555556
# Matriz de Confusao:
# [[ 8 19]
#  [13 32]]
#
# __________________________________________________________
#
#               precision    recall  f1-score   support
#
#            0       0.25      0.19      0.22        26
#            1       0.57      0.65      0.61        43
#
#     accuracy                           0.48        69
#    macro avg       0.41      0.42      0.41        69
# weighted avg       0.45      0.48      0.46        69
#
#
# Tempo do Treinamento: 0:00:19.531034	 AUC: 0.4217352415026834
# Acurácia: 0.4782608695652174
# Matriz de Confusao:
# [[ 5 21]
#  [15 28]]
#
# __________________________________________________________
#
#               precision    recall  f1-score   support
#
#            0       0.30      0.35      0.32        26
#            1       0.72      0.67      0.69        64
#
#     accuracy                           0.58        90
#    macro avg       0.51      0.51      0.51        90
# weighted avg       0.60      0.58      0.59        90
#
#
# Tempo do Treinamento: 0:00:19.745717	 AUC: 0.5090144230769231
# Acurácia: 0.5777777777777777
# Matriz de Confusao:
# [[ 9 17]
#  [21 43]]
#
# __________________________________________________________
#
#               precision    recall  f1-score   support
#
#            0       0.40      0.31      0.35        26
#            1       0.67      0.75      0.71        48
#
#     accuracy                           0.59        74
#    macro avg       0.53      0.53      0.53        74
# weighted avg       0.57      0.59      0.58        74
#
#
# Tempo do Treinamento: 0:00:19.961062	 AUC: 0.5288461538461539
# Acurácia: 0.5945945945945946
# Matriz de Confusao:
# [[ 8 18]
#  [12 36]]
#
# __________________________________________________________

# %% [markdown]
# ## Salvando Informações

# %%
# SALVAMENTO DAS INFORMAÇÕES

print('\nSalvando informações da rede......................................!')

path = RESULTS_PATH + f'/results-v{VERSION}.txt'
    
data = open(path,'w')
data.write(f"TREINAMENTO v{VERSION}\n")

data.write(f"\nModelo: {MODEL_TYPE}\t  Dataset: {DATASET_TYPE}\t ehCompleto? {ehCompleto}")

data.write("\n\nParâmetros: ")
data.write(f"\nÉpocas: {EPOCHS}\t Batch: {BATCH}\t Target Size: {TARGET}")

data.write("\n\n__________________________________________________________")
data.write("\n\nMÉTRICAS DO TREINO:")
data.write(f"\n\nAcurácias do Treino (accuracy): {train_metrics['accuracy']}")
data.write(f"\nPerdas do Treino (loss): {train_metrics['loss']}")
data.write(f"\n\nMatriz total do Treino:\n{total_train_matrix}")
#data.write(f"\n\nMédia das acurácias do Treino: {np.mean(train_metrics['accuracy'])}")
data.write(f"\nAcurácia total do Treino: {total_train_accuracy}")

data.write("\n\n__________________________________________________________")
data.write("\n\nMÉTRICAS DA VALIDAÇÃO:")
data.write(f"\n\nAcurácias do Validação (accuracy): {train_metrics['val_accuracy']}")
data.write(f"\nPerdas do Validação (loss): {train_metrics['val_loss']}")
data.write(f"\n\nMatriz total do Validação:\n{total_valid_matrix}")
#print(f"\n\nMédia das acurácias da Validação: {np.mean(train_metrics['val_accuracy'])}")
data.write(f"\nAcurácia total da Validação: {total_valid_accuracy}")

data.write("\n\n__________________________________________________________")
data.write("\n\nMÉTRICAS DO TESTE:")
data.write(f"\n\nAcurácias do Teste (accuracy): {results['test_accuracy']}")
data.write(f"\nPerdas do Teste (loss): {results['test_loss']}")
data.write(f"\n\nMatriz total do Teste:\n{total_test_matrix}")
#data.write(f"\n\nMédia das acurácias do Teste: {np.mean(history['test_accuracies'])}")
data.write(f"\nAcurácia total do Teste: {total_test_accuracy}")

data.write("\n\n__________________________________________________________")
data.write("\nMÉTRICAS PARA CADA FOLD:\n\n")
for i in range(len(results["reports"])):
    data.write(str(results["reports"][i]))
    data.write(f"\n\nTempo do Treinamento: {results['times'][i]}\t AUC: {results['AUC'][i]}")
    data.write(f"\nAcurácia: {results['test_accuracies'][i]}")
    data.write(f"\nMatriz de Confusao:\n{results['test_matrixs'][i]}")
    data.write("\n\n__________________________________________________________\n")

data.close()
# Out:
# Salvando informações da rede......................................!
